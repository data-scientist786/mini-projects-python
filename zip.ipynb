# %% [markdown]
#   # Zip

# %%
names = ['happy','laugh','shy']
emojis =['😀','🤣','😳']
z = zip(names,emojis)
print(list(z))
# Out:
# [('happy', '😀'), ('laugh', '🤣'), ('shy', '😳')]

# %% [markdown]
# # using for loop

# %%
names = ['happy', 'laugh', 'shy']
emojis = ['😀', '🤣', '😳']
z = zip(names, emojis)
for n, e in z:
    print(n, e)
# Out:
# happy 😀
# laugh 🤣
# shy 😳
